# %%
# !git pull

# %%
# !git status

# %%
# !git add git.ipynb

# %%
# !git reset HEAD
# Out:
# Unstaged changes after reset:
# M	git.ipynb

# %%
# !git rm $(git ls-files --deleted)

# %%
# !git commit -m "Updated via collab" -m "git.ipynb"

# %%
# !git push

# %%
# !git diff --staged

# %%
# !git stash

# %%
# !git stash list

# %%
# !git merge

# %% [markdown]
# # Mount GDrive and Directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/0zProject/COURSERA/

# %%
# %pwd

# %%
# !git pull

# %%
# !git status

# %%
# !git add -A

# %%
# !git rm $(git ls-files --deleted)

# %%
# !git commit -m "Updated via collab" -m "finally dealt with conflicts"

# %%
# !git push

# %%
# !git diff --staged

# %%
# !git stash

# %%
# !git stash list

# %%
# !git merge

# %% [markdown]
# # Mount GDrive and Directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/0zProject/ibm-exploratory-data-analysis-for-machine-learning/
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/0zProject/ibm-exploratory-data-analysis-for-machine-learning

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/0zProject/COURSERA'
